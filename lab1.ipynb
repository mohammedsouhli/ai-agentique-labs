# %%
from langchain_ollama import ChatOllama
from IPython.display import display, Markdown

llm = ChatOllama(model="llama3.2:3b")

response = llm.invoke([
    {"role": "system", "content": "You are a helpful assistant. The output should be in Markdown"},
    {"role": "user", "content": "C'est quoi un Agent AI"}
])

display(Markdown(response.content))
# Out:
# # Qu'est-ce qu'un Agent AI ?
#
# Un **Agent AI** (Artificial Intelligence) est un programme informatique qui simule la capacité d'une entité humaine à prendre des décisions, à apprendre et à s'adapter aux nouvelles situations. Les agents AI sont conçus pour résoudre des problèmes complexes et interactuer avec leur environnement de manière efficace.
#
# ## Caractéristiques clés des agents AI
#
# Voici quelques-unes des caractéristiques clés des agents AI :
#
# *   **Intelligence artificielle** : les agents AI sont conçus pour simuler la pensée humaine et prendre des décisions de manière autonome.
# *   **Auto-médiation** : les agents AI peuvent s'auto-médier, c'est-à-dire qu'ils peuvent ajuster leur comportement en fonction de leurs résultats passés.
# *   **Apprentissage automatique** : les agents AI peuvent apprendre à partir d'expériences et de données pour améliorer leurs performances.
# *   **Interaction avec l'environnement** : les agents AI peuvent interagir avec leur environnement, collecter des informations et prendre des actions pour atteindre leurs objectifs.
#
# ## Types d'agents AI
#
# Il existe plusieurs types d'agents AI, notamment :
#
# *   **Agent récurrent** : un agent récurrent est conçu pour traiter des séquences de données temporelles, comme les données du passé ou le modèle temporel.
# *   **Agent non récurrent** : un agent non récurrent n'est pas conçu pour traiter des séquences de données temporales et utilise généralement une stratégie basée sur l'état actuel.
# *   **Agent partially observable** : un agent partially observable est capable d'interagir avec son environnement, mais a accès limité aux informations disponibles.
#
# ## Applications des agents AI
#
# Les agents AI sont utilisés dans de nombreuses applications, notamment :
#
# *   **Systèmes d'intelligence artificielle** : les agents AI sont utilisés pour résoudre des problèmes complexes et prendre des décisions.
# *   **Assistants virtuels** : les agents AI sont utilisés pour créer des assistants virtuels capables de répondre aux questions et de fournir des informations utiles.
# *   **Jeux vidéo** : les agents AI sont utilisés pour créer des personnages intelligents dans les jeux vidéo.
#
# En résumé, un agent AI est un programme informatique conçu pour simuler la pensée humaine et prendre des décisions de manière autonome. Les agents AI sont utilisés dans de nombreuses applications et sont capables d'apprendre à partir d'expériences et de données pour améliorer leurs performances.

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4o")
print(encoding.name)

system_message = """
Perform Sentiment analysis of the review presented in the user message.
The result should be positive or negative. Do not justify your response
"""

tokens = encoding.encode(system_message)
print(len(tokens))
print(tokens)
# Out:
# o200k_base
# 28
# [198, 73751, 31712, 2581, 8450, 328, 290, 3358, 13392, 306, 290, 1825, 3176, 558, 976, 1534, 1757, 413, 8841, 503, 12626, 13, 3756, 625, 14883, 634, 3322, 198]

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from IPython.display import display, Markdown

load_dotenv()

llm2 = ChatGroq(model="llama-3.3-70b-versatile")

from langchain_core.messages import SystemMessage, HumanMessage

resp2 = llm2.invoke([
    SystemMessage("You are a helpful assistant. The output should be in Markdown"),
    HumanMessage("C'est quoi un Agent AI")
])

display(Markdown(resp2.content))
# Out:
# ### Définition d'un Agent AI
#
# Un agent AI (Intelligence Artificielle) est un système informatique conçu pour effectuer des tâches autonomes, en utilisant des algorithmes et des techniques d'apprentissage automatique pour prendre des décisions et interagir avec son environnement. Les agents AI peuvent être utilisés dans une variété de domaines, tels que la robotique, les jeux, la finance, la santé et bien d'autres.
#
# ### Caractéristiques des Agents AI
#
# Les agents AI possèdent généralement les caractéristiques suivantes :
#
# * **Autonomie** : les agents AI peuvent fonctionner de manière autonome, sans intervention humaine directe.
# * **Apprentissage** : les agents AI peuvent apprendre à partir de données et s'adapter à de nouvelles situations.
# * **Interaction** : les agents AI peuvent interagir avec leur environnement et avec d'autres agents ou systèmes.
# * **Prise de décision** : les agents AI peuvent prendre des décisions basées sur les données et les règles qu'ils ont apprises.
#
# ### Types d'Agents AI
#
# Il existe plusieurs types d'agents AI, notamment :
#
# * **Agents simples** : ces agents effectuent des tâches spécifiques et simples, telles que la reconnaissance de formes ou la classification de données.
# * **Agents cognitifs** : ces agents sont capables de raisonner et de prendre des décisions complexes, en utilisant des techniques d'apprentissage automatique et de représentation des connaissances.
# * **Agents sociaux** : ces agents interagissent avec d'autres agents ou systèmes, et peuvent apprendre à partir de leurs interactions.
#
# ### Exemples d'Agents AI
#
# Voici quelques exemples d'agents AI :
#
# * **Assistant virtuel** : un assistant virtuel comme Siri ou Alexa peut être considéré comme un agent AI, car il peut effectuer des tâches telles que la reconnaissance vocale et la recherche d'informations.
# * **Système de recommandation** : un système de recommandation comme Netflix peut être considéré comme un agent AI, car il peut apprendre les préférences des utilisateurs et leur recommander des contenus pertinents.
# * **Robotique** : les robots industriels ou les robots de service peuvent être considérés comme des agents AI, car ils peuvent effectuer des tâches autonomes et interagir avec leur environnement.

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
import json, re

load_dotenv()

system_message = """
Effectuez une analyse de sentiments basée sur les aspects des avis concernant les ordinateurs portables présentés en entrée.
Chaque avis peut comporter un ou plusieurs des aspects suivants : screen, keyboard et pad.
Pour chaque avis présenté en entrée :
- Identifiez la présence d'au moins un des trois aspects (screen, keyboard, pad).
- Attribuez une polarité de sentiment (positive, negative ou neutral) à chaque aspect.
Organisez votre réponse dans un objet JSON avec les en-têtes suivants :
  - category: [liste des aspects]
  - polarity: [liste des polarités correspondantes pour chaque aspect]
Si l'un des aspects n'est pas présent dans l'avis, supposez que la polarité est neutre.
Retournez uniquement le JSON, sans explication.
"""

llm3 = ChatGroq(model="llama-3.3-70b-versatile")

resp = llm3.invoke([
    SystemMessage(system_message),
    HumanMessage("L'écran est très bon, mais je n'ai pas aimé la souris. le clavier est correct")
])

clean = re.sub(r"```json|```", "", resp.content).strip()
result = json.loads(clean)
print(result)
print("First polarity:", result['polarity'][0])
# Out:
# {'category': ['screen', 'keyboard', 'pad'], 'polarity': ['positive', 'neutral', 'negative']}
# First polarity: positive

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
import base64

load_dotenv(override=True)  # force reload the new key

with open("key-benefits-of-ai-1.jpg", "rb") as f:
    image_data = base64.b64encode(f.read()).decode()

llm_vision = ChatGroq(model="meta-llama/llama-4-scout-17b-16e-instruct")

response = llm_vision.invoke([
    HumanMessage(content=[
        {"type": "text", "text": "Décris cette image en français"},
        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_data}"}}
    ])
])

print(response.content)
# Out:
# L'image présente un graphique à barres intitulé « Taille du marché mondial de l'IA » qui illustre la croissance projetée du marché de l'intelligence artificielle (IA) de 2025 à 2030. Le graphique à barres montre une augmentation progressive de la taille du marché :
#
# 2025 : 243,72 millions
# 2026 : 320,14 millions
# 2027 : 415,61 millions
# 2028 : 529,23 millions
# 2029 : 667,74 millions
# 2030 : 826,73 millions
#
# À droite du graphique, des informations supplémentaires sont fournies sous le titre « Focus sur la croissance de l'IA » :
#
# 1. D'ici 2032, les ventes générées par l'IA devraient atteindre 1,3 billion de dollars.
# 2. 72 % des entreprises dans le monde utilisent l'IA.
#
# Le logo de l'agence de marketing digital « DIGITALSILK » apparaît en bas à droite. Cette image suggère que l'IA est en plein essor, avec une croissance significative prévue dans les prochaines années.
